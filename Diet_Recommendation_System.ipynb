# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv(r"C:\Users\Prabal Kuinkel\Desktop\Data Analyst\100-Days-of-ML\Data-sets\Diet.csv")

# %%
df.head()
# Out:
#              Food_items  Breakfast  Lunch  Dinner  VegNovVeg  Junk Food  \
# 0      Asparagus Cooked          0      1       1          0          0
# 1              Avocados          1      0       0          0          0
# 2               Bananas          1      0       0          0          0
# 3  Bagels made in wheat          0      1       1          0          1
# 4               Berries          1      0       0          0          0
#
#    Calories  Fats  Proteins  Iron  Calcium  Sodium  Potassium  Carbohydrates  \
# 0        22   0.2       2.4  0.91     23.0    14.0      224.0            4.1
# 1       160  15.0       2.0  0.55     12.0     7.0      485.0            8.5
# 2        89   0.3       1.1  0.26      5.0     1.0      358.0           23.0
# 3       250   1.5      10.0  2.76     20.0   439.0      165.0           49.0
# 4       349   0.4      14.0  6.80    190.0   298.0       77.0           77.0
#
#    Fibre  VitaminD  Sugars
# 0    2.0         0     1.3
# 1    6.7         0     0.7
# 2    2.6         0    12.0
# 3    4.1         0     6.1
# 4   13.0         0    46.0

# %%
df.sample(20)
# Out:
#                   Food_items  Breakfast  Lunch  Dinner  VegNovVeg  Junk Food  \
# 66                 Goat meat          0      1       1          1          0
# 142                  Malpuwa          1      0       1          0          0
# 24             Peproni Pizza          0      0       1          0          1
# 144            Keema Noodles          0      1       0          0          1
# 115                    Barfi          0      1       0          0          0
# 128         chicken sausages          0      1       0          1          1
# 40                   Brownie          1      0       0          0          0
# 78             Turkey cooked          0      1       1          1          0
# 72   Spaghetti and meatballs          0      0       1          1          1
# 42                   Uttapam          1      1       1          0          0
# 39                    Yogurt          1      1       1          0          0
# 116                   Sukuti          0      1       1          0          0
# 130                  Rikikur          0      1       1          0          1
# 68            Chicken Strips          0      0       1          1          0
# 20            Protein Powder          1      0       0          0          0
# 157            Hide and Sick          1      1       0          0          0
# 11           Dark chocolates          0      0       1          0          1
# 113                     jeri          0      1       0          0          0
# 84         Vanilla Ice cream          0      0       1          0          1
# 145                   Dhikri          1      0       1          0          0
#
#      Calories  Fats  Proteins    Iron  Calcium  Sodium  Potassium  \
# 66        109   2.3      21.0   2.830     13.0    82.0      385.0
# 142        88   4.0       3.0   0.720      0.0    46.0        0.0
# 24        298  14.0      12.0   2.140    146.0   692.0      199.0
# 144       190   7.0       4.0   1.440     20.0   790.0        0.0
# 115        84   4.0       1.0   0.000     50.0     1.0       25.0
# 128       140   8.0      15.0   1.080     20.0   470.0        0.0
# 40        407   6.2       4.4   3.810     17.0   457.0       51.0
# 78        203  10.0      27.0   1.520     28.0    78.0      294.0
# 72        170   8.5       7.8   1.290     45.0   351.0      206.0
# 42        188   7.2       4.4  24.000      6.4   522.0       91.0
# 39         60   4.0       3.1   0.080    183.0    70.0      234.0
# 116       289   6.7      53.9   0.000      0.0     3.7        0.0
# 130       268  14.8       6.1   1.674     32.0   764.0      622.0
# 68        295  15.0      19.0   0.720     11.0   798.0      334.0
# 20        411  17.0      46.0   8.570    500.0   329.0     1129.0
# 157       750  27.0       9.0   2.700      0.0   165.0        0.0
# 11        556  32.0       5.5   2.130     30.0     6.0      502.0
# 113       200   2.0       1.2   0.000      0.0     1.0       25.0
# 84        207  11.0       3.5   0.090    128.0    80.0      199.0
# 145       204   2.0       4.0   0.000      0.0     0.0        0.0
#
#      Carbohydrates  Fibre  VitaminD  Sugars
# 66            57.0    0.0         0    0.00
# 142            9.0    0.0         0   12.00
# 24            30.0    1.8         0    3.20
# 144           26.0    1.0         0    1.00
# 115           10.0    0.0         0   13.00
# 128            2.0    1.0         0    0.01
# 40            84.0    2.9         0   55.00
# 78             0.0    0.0         8    0.00
# 72            16.0    1.5         0    2.00
# 42            26.4    2.2         0    0.24
# 39             7.0    0.0         1    7.00
# 116            3.3    0.0         0    1.50
# 130           27.8    3.3         0    1.80
# 68            22.0    1.1         0    0.30
# 20            19.0    7.1       200    5.70
# 157          120.0    0.0         0   63.00
# 11            60.0    6.5         0   48.00
# 113           31.0    0.3         0   20.10
# 84            24.0    0.7         0   21.00
# 145           42.0    0.0         0    0.00

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 159 entries, 0 to 158
# Data columns (total 17 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Food_items     159 non-null    object
#  1   Breakfast      159 non-null    int64
#  2   Lunch          159 non-null    int64
#  3   Dinner         159 non-null    int64
#  4   VegNovVeg      159 non-null    int64
#  5   Junk Food      159 non-null    int64
#  6   Calories       159 non-null    int64
#  7   Fats           159 non-null    float64
#  8   Proteins       159 non-null    float64
#  9   Iron           159 non-null    float64
#  10  Calcium        159 non-null    float64
#  11  Sodium         159 non-null    float64
#  12  Potassium      159 non-null    float64
#  13  Carbohydrates  159 non-null    float64
#  14  Fibre          159 non-null    float64
#  15  VitaminD       159 non-null    int64
#  16  Sugars         159 non-null    float64
# dtypes: float64(9), int64(7), object(1)
# memory usage: 21.2+ KB

# %%
df.describe()
# Out:
#         Breakfast       Lunch      Dinner   VegNovVeg   Junk Food    Calories  \
# count  159.000000  159.000000  159.000000  159.000000  159.000000  159.000000
# mean     0.333333    0.679245    0.610063    0.188679    0.270440  218.861635
# std      0.472894    0.468241    0.489277    0.392490    0.445591  171.892463
# min      0.000000    0.000000    0.000000    0.000000    0.000000    1.000000
# 25%      0.000000    0.000000    0.000000    0.000000    0.000000   94.000000
# 50%      0.000000    1.000000    1.000000    0.000000    0.000000  172.000000
# 75%      1.000000    1.000000    1.000000    0.000000    1.000000  318.500000
# max      1.000000    1.000000    1.000000    1.000000    1.000000  812.000000
#
#              Fats    Proteins        Iron      Calcium        Sodium  \
# count  159.000000  159.000000  159.000000   159.000000    159.000000
# mean     8.431447   10.208805    2.937956    97.163289    395.671132
# std     10.395356   12.253805    7.120662   220.205893   1595.542612
# min      0.000000    0.000000    0.000000     0.000000      0.000000
# 25%      0.900000    2.250000    0.095000     2.000000      5.000000
# 50%      4.400000    5.200000    0.840000    17.000000     70.000000
# 75%     12.000000   13.900000    2.241000    64.000000    370.500000
# max     50.000000   53.900000   57.000000  1250.000000  19506.000000
#
#          Potassium  Carbohydrates       Fibre    VitaminD      Sugars
# count   159.000000     159.000000  159.000000  159.000000  159.000000
# mean    183.954717      26.238994    2.474214    6.446541    6.812390
# std     219.477662      26.132888    4.490922   44.456727   14.374944
# min       0.000000       0.000000    0.000000    0.000000    0.000000
# 25%       0.300000       6.500000    0.000000    0.000000    0.000000
# 50%     123.100000      19.000000    1.000000    0.000000    0.900000
# 75%     276.500000      35.500000    2.700000    0.000000    5.700000
# max    1129.000000     120.000000   34.000000  435.000000   82.000000

# %%
row_count,column_count=df.shape

# %%
print('The number of rows',row_count)
# Out:
# The number of rows 159

# %%
print('The number of column',column_count)
# Out:
# The number of column 17

# %%
breakfast_items = df[df['Breakfast'] == 1][['Food_items', 'VegNovVeg', 'Junk Food', 'Calories', 'Fats', 'Proteins', 'Iron', 'Calcium', 'Sodium', 'Potassium', 'Carbohydrates', 'Fibre', 'VitaminD', 'Sugars']]

# %%
breakfast_items.head()
# Out:
#         Food_items  VegNovVeg  Junk Food  Calories  Fats  Proteins  Iron  \
# 1         Avocados          0          0       160  15.0       2.0  0.55
# 2          Bananas          0          0        89   0.3       1.1  0.26
# 4          Berries          0          0       349   0.4      14.0  6.80
# 8  American cheese          0          0       331  24.0      20.0  0.84
# 9           Coffee          0          0         2   0.0       0.3  0.02
#
#    Calcium  Sodium  Potassium  Carbohydrates  Fibre  VitaminD  Sugars
# 1     12.0     7.0      485.0            8.5    6.7         0     0.7
# 2      5.0     1.0      358.0           23.0    2.6         0    12.0
# 4    190.0   298.0       77.0           77.0   13.0         0    46.0
# 8    497.0   966.0      363.0            8.3    0.0         0     0.0
# 9      2.0     1.0       50.0            0.2    0.0         0     0.0

# %%
breakfast_items.to_csv('Data-sets/breakfast_items.csv')

# %%
Lunch_items = df[df['Lunch'] == 1][['Food_items', 'VegNovVeg', 'Junk Food', 'Calories', 'Fats', 'Proteins', 'Iron', 'Calcium', 'Sodium', 'Potassium', 'Carbohydrates', 'Fibre', 'VitaminD', 'Sugars']]

# %%
Lunch_items.head()
# Out:
#              Food_items  VegNovVeg  Junk Food  Calories  Fats  Proteins  Iron  \
# 0      Asparagus Cooked          0          0        22   0.2       2.4  0.91
# 3  Bagels made in wheat          0          1       250   1.5      10.0  2.76
# 5              Brocolli          0          0        25   0.5       3.8  1.27
# 6            Brown Rice          0          0       362   2.7       7.5  1.80
# 7           Cauliflower          0          0        32   0.3       3.0  0.72
#
#    Calcium  Sodium  Potassium  Carbohydrates  Fibre  VitaminD  Sugars
# 0     23.0    14.0      224.0            4.1    2.0         0     1.3
# 3     20.0   439.0      165.0           49.0    4.1         0     6.1
# 5    118.0    56.0      343.0            3.1    2.8         0     0.6
# 6     33.0     4.0      268.0           76.0    3.4         0     0.0
# 7     32.0   259.0      278.0            6.3    3.3         0     0.0

# %%
Lunch_items.to_csv('Data-sets/lunch_items.csv')

# %%
Dinner_items=df[df['Dinner']==1][['Food_items', 'VegNovVeg', 'Junk Food', 'Calories', 'Fats', 'Proteins', 'Iron', 'Calcium', 'Sodium', 'Potassium', 'Carbohydrates', 'Fibre', 'VitaminD', 'Sugars']]

# %%
Dinner_items.head()
# Out:
#              Food_items  VegNovVeg  Junk Food  Calories  Fats  Proteins  Iron  \
# 0      Asparagus Cooked          0          0        22   0.2       2.4  0.91
# 3  Bagels made in wheat          0          1       250   1.5      10.0  2.76
# 5              Brocolli          0          0        25   0.5       3.8  1.27
# 6            Brown Rice          0          0       362   2.7       7.5  1.80
# 7           Cauliflower          0          0        32   0.3       3.0  0.72
#
#    Calcium  Sodium  Potassium  Carbohydrates  Fibre  VitaminD  Sugars
# 0     23.0    14.0      224.0            4.1    2.0         0     1.3
# 3     20.0   439.0      165.0           49.0    4.1         0     6.1
# 5    118.0    56.0      343.0            3.1    2.8         0     0.6
# 6     33.0     4.0      268.0           76.0    3.4         0     0.0
# 7     32.0   259.0      278.0            6.3    3.3         0     0.0

# %%
Dinner_items.to_csv('Data-sets/dinner_items.csv')

# %%
import csv
from sklearn.neighbors import NearestNeighbors
from sklearn.cluster import KMeans
import pandas as pd

class VfcDietRecommendation:
    def __init__(self, age, height, weight, activity_level, body_type):
        self.age = age
        self.height = height
        self.weight = weight
        self.activity_level = activity_level
        self.body_type = body_type
        self.bmr = self.calculate_bmr()

    def calculate_bmr(self):
        if self.body_type == "endomorphic":
            return (10 * self.weight) + (6.25 * self.height) - (5 * self.age) - 161
        elif self.body_type == "ectomorphic":
            return (10 * self.weight) + (6.25 * self.height) - (5 * self.age) + 5
        elif self.body_type == "mesomorphic":
            return (10 * self.weight) + (6.25 * self.height) - (5 * self.age) + 100

    def calculate_calories(self, goal):
        bmr = self.bmr

        if self.activity_level == "sedentary":
            bmr *= 1.2
        elif self.activity_level == "lightly_active":
            bmr *= 1.375
        elif self.activity_level == "moderately_active":
            bmr *= 1.55
        elif self.activity_level == "very_active":
            bmr *= 1.725
        elif self.activity_level == "extra_active":
            bmr *= 1.9

        if goal == "weight_loss":
            return bmr * 0.8
        elif goal == "weight_gain":
            return bmr * 1.2

    def load_food_items(self, csv_file):
        food_items = []
        with open(csv_file, 'r') as file:
            reader = csv.DictReader(file)
            for row in reader:
                food_items.append(row)
        return food_items

    def select_meal(self, food_items, target_calories):
        closest_meal = None
        closest_distance = float('inf')

        for meal in food_items:
            calorie_count = int(meal['Calories'])
            distance = abs(calorie_count - target_calories)

            if distance < closest_distance:
                closest_meal = meal
                closest_distance = distance

        return closest_meal

    def recommend_diet(self, goal, breakfast_csv, lunch_csv, dinner_csv):
        total_calories = self.calculate_calories(goal)

        if goal == "weight_loss":
            breakfast_percentage = 0.3  # 30% of total calories
            lunch_percentage = 0.4  # 40% of total calories
            dinner_percentage = 0.3  # 30% of total calories
        elif goal == "weight_gain":
            breakfast_percentage = 0.25  # 25% of total calories
            lunch_percentage = 0.35  # 35% of total calories
            dinner_percentage = 0.4  # 40% of total calories

        breakfast_calories = total_calories * breakfast_percentage
        lunch_calories = total_calories * lunch_percentage
        dinner_calories = total_calories * dinner_percentage

        breakfast_items = self.load_food_items(breakfast_csv)
        lunch_items = self.load_food_items(lunch_csv)
        dinner_items = self.load_food_items(dinner_csv)

        recommended_diet = {
            "Breakfast": {"Items": [], "Total Calories": 0},
            "Lunch": {"Items": [], "Total Calories": 0},
            "Dinner": {"Items": [], "Total Calories": 0},
        }

        breakfast_meal = self.select_meal(breakfast_items, breakfast_calories)
        lunch_meal = self.select_meal(lunch_items, lunch_calories)
        dinner_meal = self.select_meal(dinner_items, dinner_calories)

        recommended_diet["Breakfast"]["Items"].append(breakfast_meal)
        recommended_diet["Lunch"]["Items"].append(lunch_meal)
        recommended_diet["Dinner"]["Items"].append(dinner_meal)

        if breakfast_meal:
            recommended_diet["Breakfast"]["Total Calories"] += int(breakfast_meal["Calories"])
        if lunch_meal:
            recommended_diet["Lunch"]["Total Calories"] += int(lunch_meal["Calories"])
        if dinner_meal:
            recommended_diet["Dinner"]["Total Calories"] += int(dinner_meal["Calories"])

        return recommended_diet

class DietRecommendationSystem:
    def __init__(self, user):
        self.user = user
        self.breakfast_items = pd.read_csv("Data-sets/breakfast_items.csv")
        self.lunch_items = pd.read_csv("Data-sets/lunch_items.csv")
        self.dinner_items = pd.read_csv("Data-sets/dinner_items.csv")

    def knn_recommendation(self, meal_items, target_calories, k=5):
        X = meal_items[['Calories']].values
        nbrs = NearestNeighbors(n_neighbors=k, algorithm='auto').fit(X)
        distances, indices = nbrs.kneighbors([[target_calories]])
        recommended_items = meal_items.iloc[indices[0]]
        return recommended_items

    def kmeans_recommendation(self, meal_items, target_calories, k=3):
        X = meal_items[['Calories']].values
        kmeans = KMeans(n_clusters=k, random_state=42).fit(X)
        cluster_centers = kmeans.cluster_centers_
        distances = [abs(calories - target_calories) for calories in cluster_centers[:, 0]]
        closest_cluster_index = distances.index(min(distances))
        cluster_items = meal_items[kmeans.labels_ == closest_cluster_index]
        return cluster_items

    def recommend_diet_knn(self, goal):
        total_calories = self.user.calculate_calories(goal)
        breakfast_calories = total_calories * 0.3
        lunch_calories = total_calories * 0.4
        dinner_calories = total_calories * 0.3

        recommended_diet = {
            "Breakfast": self.knn_recommendation(self.breakfast_items, breakfast_calories),
            "Lunch": self.knn_recommendation(self.lunch_items, lunch_calories),
            "Dinner": self.knn_recommendation(self.dinner_items, dinner_calories)
        }

        return recommended_diet

    def recommend_diet_kmeans(self, goal):
        total_calories = self.user.calculate_calories(goal)
        breakfast_calories = total_calories * 0.3
        lunch_calories = total_calories * 0.4
        dinner_calories = total_calories * 0.3

        recommended_diet = {
            "Breakfast": self.kmeans_recommendation(self.breakfast_items, breakfast_calories),
            "Lunch": self.kmeans_recommendation(self.lunch_items, lunch_calories),
            "Dinner": self.kmeans_recommendation(self.dinner_items, dinner_calories)
        }

        return recommended_diet

# Define the variables
age = 20
height = 167.64
weight = 54
activity_level = "moderately_active"
body_type = "ectomorphic"

# Usage
user = VfcDietRecommendation(age, height, weight, activity_level, body_type)
diet_system = DietRecommendationSystem(user)

# K-NN recommendation
recommended_diet_knn = diet_system.recommend_diet_knn("weight_gain")
print("\nRecommended Diet for Weight Gain (K-NN):")
print("Breakfast:\n", recommended_diet_knn["Breakfast"])
print("Lunch:\n", recommended_diet_knn["Lunch"])
print("Dinner:\n", recommended_diet_knn["Dinner"])

# K-Means recommendation
recommended_diet_kmeans = diet_system.recommend_diet_kmeans("weight_gain")
print("\nRecommended Diet for Weight Gain (K-Means):")
print("Breakfast:\n", recommended_diet_kmeans["Breakfast"])
print("Lunch:\n", recommended_diet_kmeans["Lunch"])
print("Dinner:\n", recommended_diet_kmeans["Dinner"])
# Out:
# Recommended Diet for Weight Gain (K-NN):
# Breakfast:
#      Unnamed: 0     Food_items  VegNovVeg  Junk Food  Calories  Fats  Proteins  \
# 51         157  Hide and Sick          0          0       750  27.0       9.0
# 22          45        Almonds          0          0       579  50.0      21.0
# 49         154   chana masala          0          0       565  10.4      18.5
# 8           14    Cashew Nuts          0          0       553  44.0      18.0
# 43         121   khajuri puff          0          1       551  28.0       8.0
#
#     Iron  Calcium  Sodium  Potassium  Carbohydrates  Fibre  VitaminD  Sugars
# 51  2.70      0.0   165.0        0.0          120.0    0.0         0    63.0
# 22  3.71    269.0     1.0      733.0           22.0   13.0         0     4.4
# 49  3.51     84.0   300.0      311.0           92.0    7.3         0     0.1
# 8   6.68     37.0    12.0      660.0           30.0    3.3         0     5.9
# 43  0.00      0.0     0.0        0.0           50.0    0.0         0     0.7
# Lunch:
#       Unnamed: 0            Food_items  VegNovVeg  Junk Food  Calories  Fats  \
# 47           91   Fried Chicken momos          1          1       812  33.8
# 106         157         Hide and Sick          0          0       750  27.0
# 48           92      fried buff momos          1          1       620  22.0
# 45           89    Steamed Buff momos          1          1       590  30.0
# 46           90  Steamed chicken Momo          1          1       565  13.0
#
#      Proteins   Iron  Calcium  Sodium  Potassium  Carbohydrates  Fibre  \
# 47       45.2  0.000     0.00  2500.0        0.0           80.8    0.0
# 106       9.0  2.700     0.00   165.0        0.0          120.0    0.0
# 48       34.0  1.122     0.17   112.0     1021.0           72.0    4.0
# 45       30.0  0.000     0.00  3130.0        0.0           70.0    1.0
# 46       26.6  0.000     0.00  2500.0        0.0           85.0    1.6
#
#      VitaminD  Sugars
# 47          0     0.0
# 106         0    63.0
# 48          0     4.0
# 45          0     0.0
# 46          0     1.6
# Dinner:
#      Unnamed: 0       Food_items  VegNovVeg  Junk Food  Calories  Fats  \
# 96         154     chana masala          0          0       565  10.4
# 6           11  Dark chocolates          0          1       556  32.0
# 65         107  chicken choilaa          1          0       541  40.0
# 78         124   Dahi puri chat          0          1       489   5.0
# 63         105        Aloo Tama          0          0       482  20.0
#
#     Proteins   Iron  Calcium  Sodium  Potassium  Carbohydrates  Fibre  \
# 96      18.5  3.510     84.0   300.0      311.0           92.0    7.3
# 6        5.5  2.130     30.0     6.0      502.0           60.0    6.5
# 65      43.0  0.000      0.0     0.0        0.0            2.0    0.0
# 78      16.0  1.260    500.0   745.0      773.0           30.0    1.0
# 63      10.0  0.702   1250.0     0.0        0.0           65.5    0.8
#
#     VitaminD  Sugars
# 96         0     0.1
# 6          0    48.0
# 65         0     0.0
# 78         0    20.0
# 63         0     0.1
# C:\Python anaconda setip 2.0\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\Python anaconda setip 2.0\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Python anaconda setip 2.0\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\Python anaconda setip 2.0\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Python anaconda setip 2.0\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\Python anaconda setip 2.0\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# Recommended Diet for Weight Gain (K-Means):
# Breakfast:
#      Unnamed: 0      Food_items  VegNovVeg  Junk Food  Calories  Fats  \
# 8           14     Cashew Nuts          0          0       553  44.0
# 22          45         Almonds          0          0       579  50.0
# 31          55      Chia seeds          0          0       486  31.0
# 38          80     Beef sticks          1          0       550  50.0
# 39          81    Banana Chips          0          0       519  34.0
# 41          87  Chocolate milk          0          1       535  30.0
# 43         121    khajuri puff          0          1       551  28.0
# 49         154    chana masala          0          0       565  10.4
# 51         157   Hide and Sick          0          0       750  27.0
#
#     Proteins  Iron  Calcium  Sodium  Potassium  Carbohydrates  Fibre  \
# 8       18.0  6.68     37.0    12.0      660.0           30.0    3.3
# 22      21.0  3.71    269.0     1.0      733.0           22.0   13.0
# 31      17.0  7.72    631.0    16.0      407.0           42.0   34.0
# 38      22.0  3.40     68.0  1531.0      257.0            5.4    0.0
# 39       2.3  1.25     18.0     6.0      536.0           58.0    7.7
# 41       7.7  2.35    189.0    79.0      372.0           59.0    3.4
# 43       8.0  0.00      0.0     0.0        0.0           50.0    0.0
# 49      18.5  3.51     84.0   300.0      311.0           92.0    7.3
# 51       9.0  2.70      0.0   165.0        0.0          120.0    0.0
#
#     VitaminD  Sugars
# 8          0     5.9
# 22         0     4.4
# 31         0     0.0
# 38         0     0.0
# 39         0    35.0
# 41         0    52.0
# 43         0     0.7
# 49         0     0.1
# 51         0    63.0
# Lunch:
#       Unnamed: 0            Food_items  VegNovVeg  Junk Food  Calories  Fats  \
# 15           30       Sugar Doughnuts          0          1       426  23.0
# 16           31   Chocolate Doughnuts          0          1       452  25.0
# 45           89    Steamed Buff momos          1          1       590  30.0
# 46           90  Steamed chicken Momo          1          1       565  13.0
# 47           91   Fried Chicken momos          1          1       812  33.8
# 48           92      fried buff momos          1          1       620  22.0
# 51           95       current Noodles          0          1       485  22.0
# 61          105             Aloo Tama          0          0       482  20.0
# 62          106        chicken sekuwa          1          0       450   8.0
# 63          107       chicken choilaa          1          0       541  40.0
# 77          124        Dahi puri chat          0          1       489   5.0
# 84          131        Bhatmas Sadeko          0          0       445  13.0
# 85          132             Anda Bara          1          0       499  24.3
# 104         154          chana masala          0          0       565  10.4
# 106         157         Hide and Sick          0          0       750  27.0
#
#      Proteins   Iron  Calcium  Sodium  Potassium  Carbohydrates  Fibre  \
# 15        5.2  1.060    60.00   402.0      102.0           51.0    1.5
# 16        4.9  4.000    24.00   326.0      201.0           51.0    1.9
# 45       30.0  0.000     0.00  3130.0        0.0           70.0    1.0
# 46       26.6  0.000     0.00  2500.0        0.0           85.0    1.6
# 47       45.2  0.000     0.00  2500.0        0.0           80.8    0.0
# 48       34.0  1.122     0.17   112.0     1021.0           72.0    4.0
# 51       10.0  1.500    12.00  1150.0      115.0           63.0    0.8
# 61       10.0  0.702  1250.00     0.0        0.0           65.5    0.8
# 62       33.0  0.000     0.00   700.0        0.0           63.0    0.0
# 63       43.0  0.000     0.00     0.0        0.0            2.0    0.0
# 77       16.0  1.260   500.00   745.0      773.0           30.0    1.0
# 84        8.8  0.000     0.00     0.0        0.0           73.7    0.0
# 85       13.8  0.000     0.00     0.0        0.0           45.6   13.5
# 104      18.5  3.510    84.00   300.0      311.0           92.0    7.3
# 106       9.0  2.700     0.00   165.0        0.0          120.0    0.0
#
#      VitaminD  Sugars
# 15          0    32.0
# 16          0    27.0
# 45          0     0.0
# 46          0     1.6
# 47          0     0.0
# 48          0     4.0
# 51          0     0.0
# 61          0     0.1
# 62          0     4.0
# 63          0     0.0
# 77          0    20.0
# 84          0     0.0
# 85          0    12.0
# 104         0     0.1
# 106         0    63.0
# Dinner:
#      Unnamed: 0           Food_items  VegNovVeg  Junk Food  Calories  Fats  \
# 3            6           Brown Rice          0          0       362   2.7
# 6           11      Dark chocolates          0          1       556  32.0
# 20          30      Sugar Doughnuts          0          1       426  23.0
# 21          31  Chocolate Doughnuts          0          1       452  25.0
# 22          32   Pop Corn - Caramel          0          0       381   1.4
# 23          33             Pop Corn          0          0       429   9.5
# 34          50           White Rice          0          0       360   0.6
# 51          76               Nachos          0          0       350  22.0
# 52          77      Chicken Popcorn          1          0       351  22.0
# 60          88         Rice Pudding          0          0       376   0.1
# 63         105            Aloo Tama          0          0       482  20.0
# 64         106       chicken sekuwa          1          0       450   8.0
# 65         107      chicken choilaa          1          0       541  40.0
# 78         124       Dahi puri chat          0          1       489   5.0
# 82         131       Bhatmas Sadeko          0          0       445  13.0
# 85         137           Dhal Bhatt          0          0       350   0.7
# 96         154         chana masala          0          0       565  10.4
#
#     Proteins   Iron  Calcium  Sodium  Potassium  Carbohydrates  Fibre  \
# 3        7.5  1.800     33.0     4.0      268.0           76.0    3.4
# 6        5.5  2.130     30.0     6.0      502.0           60.0    6.5
# 20       5.2  1.060     60.0   402.0      102.0           51.0    1.5
# 21       4.9  4.000     24.0   326.0      201.0           51.0    1.9
# 22       2.0  0.800     18.0   286.0      110.0           90.0    2.5
# 23      13.0  2.280     11.0   490.0      241.0           73.0   14.0
# 34       6.6  4.360      9.0     1.0       86.0           79.0    1.4
# 51       4.3  0.750     63.0   313.0      362.0           35.0    3.2
# 52      18.0  1.420     32.0  1140.0      288.0           21.0    1.0
# 60       2.7  1.790     14.0   366.0        5.0           91.0    0.7
# 63      10.0  0.702   1250.0     0.0        0.0           65.5    0.8
# 64      33.0  0.000      0.0   700.0        0.0           63.0    0.0
# 65      43.0  0.000      0.0     0.0        0.0            2.0    0.0
# 78      16.0  1.260    500.0   745.0      773.0           30.0    1.0
# 82       8.8  0.000      0.0     0.0        0.0           73.7    0.0
# 85       3.2  0.001     48.0     2.0       30.0            0.4    0.1
# 96      18.5  3.510     84.0   300.0      311.0           92.0    7.3
#
#     VitaminD  Sugars
# 3          0     0.0
# 6          0    48.0
# 20         0    32.0
# 21         0    27.0
# 22         0    65.0
# 23         0     0.5
# 34         0     0.0
# 51         0     2.2
# 52         0     0.0
# 60         0     0.0
# 63         0     0.1
# 64         0     4.0
# 65         0     0.0
# 78         0    20.0
# 82         0     0.0
# 85         0     0.2
# 96         0     0.1
