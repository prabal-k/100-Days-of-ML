# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
df = pd.read_csv("Data-sets/Diet.csv")

# %%
df
# Out:
#                Food_items  Breakfast  Lunch  Dinner  VegNovVeg  Junk Food  \
# 0        Asparagus Cooked          0      1       1          0          0
# 1                Avocados          1      0       0          0          0
# 2                 Bananas          1      0       0          0          0
# 3    Bagels made in wheat          0      1       1          0          1
# 4                 Berries          1      0       0          0          0
# ..                    ...        ...    ...     ...        ...        ...
# 154          chana masala          1      1       1          0          0
# 155       chini ko laddhu          0      1       0          0          0
# 156    Digestive Biscuits          1      0       0          0          0
# 157         Hide and Sick          1      1       0          0          0
# 158                Donuts          1      1       0          0          0
#
#      Calories  Fats  Proteins   Iron  Calcium  Sodium  Potassium  \
# ...

# %%
df.sample(20)
# Out:
#                Food_items  Breakfast  Lunch  Dinner  VegNovVeg  Junk Food  \
# 151                Tongba          0      0       1          0          0
# 158                Donuts          1      1       0          0          0
# 29       Chicken Sandwich          0      1       1          1          1
# 16                 Orange          1      0       0          0          0
# 122               dhungri          0      1       0          0          0
# 3    Bagels made in wheat          0      1       1          0          1
# 58    Cereals-Corn Flakes          1      0       0          0          0
# 90   Steamed chicken Momo          0      1       0          1          1
# 76                 Nachos          1      1       1          0          0
# 98              pani puri          0      1       0          0          1
# 39                 Yogurt          1      1       1          0          0
# 21                Pumpkin          0      1       1          0          0
# ...

# %%
df.isnull().sum()
# Out:
# Food_items       0
# Breakfast        0
# Lunch            0
# Dinner           0
# VegNovVeg        0
# Junk Food        0
# Calories         0
# Fats             0
# Proteins         0
# Iron             0
# Calcium          0
# Sodium           0
# Potassium        0
# Carbohydrates    0
# Fibre            0
# VitaminD         0
# Sugars           0
# dtype: int64

# %%
df.describe()
# Out:
#         Breakfast       Lunch      Dinner   VegNovVeg   Junk Food    Calories  \
# count  159.000000  159.000000  159.000000  159.000000  159.000000  159.000000
# mean     0.333333    0.679245    0.610063    0.188679    0.270440  218.861635
# std      0.472894    0.468241    0.489277    0.392490    0.445591  171.892463
# min      0.000000    0.000000    0.000000    0.000000    0.000000    1.000000
# 25%      0.000000    0.000000    0.000000    0.000000    0.000000   94.000000
# 50%      0.000000    1.000000    1.000000    0.000000    0.000000  172.000000
# 75%      1.000000    1.000000    1.000000    0.000000    1.000000  318.500000
# max      1.000000    1.000000    1.000000    1.000000    1.000000  812.000000
#
#              Fats    Proteins        Iron      Calcium        Sodium  \
# count  159.000000  159.000000  159.000000   159.000000    159.000000
# mean     8.431447   10.208805    2.937956    97.163289    395.671132
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 159 entries, 0 to 158
# Data columns (total 17 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Food_items     159 non-null    object
#  1   Breakfast      159 non-null    int64
#  2   Lunch          159 non-null    int64
#  3   Dinner         159 non-null    int64
#  4   VegNovVeg      159 non-null    int64
#  5   Junk Food      159 non-null    int64
#  6   Calories       159 non-null    int64
#  7   Fats           159 non-null    float64
#  8   Proteins       159 non-null    float64
#  9   Iron           159 non-null    float64
#  10  Calcium        159 non-null    float64
#  11  Sodium         159 non-null    float64
#  12  Potassium      159 non-null    float64
#  13  Carbohydrates  159 non-null    float64
#  14  Fibre          159 non-null    float64
#  15  VitaminD       159 non-null    int64
#  16  Sugars         159 non-null    float64
# ...

# %%
df.columns
# Out:
# Index(['Food_items', 'Breakfast', 'Lunch', 'Dinner', 'VegNovVeg', 'Junk Food',
#        'Calories', 'Fats', 'Proteins', 'Iron', 'Calcium', 'Sodium',
#        'Potassium', 'Carbohydrates', 'Fibre', 'VitaminD', 'Sugars'],
#       dtype='object')

# %%
cat_col = [c for c in df.columns if df[c].dtype == 'object']
num_col = [c for c in df.columns if df[c].dtype!='object']

# %%
df.shape[0]
# Out:
# 159

# %%
print("categorical columns : ",cat_col)
print('Numerical columns : ',num_col)
# Out:
# categorical columns :  ['Food_items']
# Numerical columns :  ['Breakfast', 'Lunch', 'Dinner', 'VegNovVeg', 'Junk Food', 'Calories', 'Fats', 'Proteins', 'Iron', 'Calcium', 'Sodium', 'Potassium', 'Carbohydrates', 'Fibre', 'VitaminD', 'Sugars']

# %%
#Dinner dataset
dinner_df=df[df['Dinner']==1][['Food_items','VegNovVeg','Junk Food','Calories', 'Fats', 'Proteins', 'Iron', 'Calcium', 'Sodium', 'Potassium', 'Carbohydrates', 'Fibre', 'VitaminD', 'Sugars']]
dinner_df.to_csv('Data-sets/dinner')

# %%
dinner_df
# Out:
#                Food_items  VegNovVeg  Junk Food  Calories  Fats  Proteins  \
# 0        Asparagus Cooked          0          0        22   0.2       2.4
# 3    Bagels made in wheat          0          1       250   1.5      10.0
# 5                Brocolli          0          0        25   0.5       3.8
# 6              Brown Rice          0          0       362   2.7       7.5
# 7             Cauliflower          0          0        32   0.3       3.0
# ..                    ...        ...        ...       ...   ...       ...
# 145                Dhikri          0          0       204   2.0       4.0
# 146          kodo ko roti          0          0       325   1.0       7.0
# 147        fapher ko roti          0          0       115   7.0       3.0
# 151                Tongba          0          0       100   1.0      50.0
# 154          chana masala          0          0       565  10.4      18.5
#
#       Iron  Calcium  Sodium  Potassium  Carbohydrates  Fibre  VitaminD  Sugars
# ...

# %%
#lunch_data datas
lunch_df=df[df['Lunch']==1][['Food_items','VegNovVeg','Junk Food','Calories', 'Fats', 'Proteins', 'Iron', 'Calcium', 'Sodium', 'Potassium', 'Carbohydrates', 'Fibre', 'VitaminD', 'Sugars']]
lunch_df.to_csv('Data-sets/lunch')

# %%
lunch_df
# Out:
#                Food_items  VegNovVeg  Junk Food  Calories  Fats  Proteins  \
# 0        Asparagus Cooked          0          0        22   0.2       2.4
# 3    Bagels made in wheat          0          1       250   1.5      10.0
# 5                Brocolli          0          0        25   0.5       3.8
# 6              Brown Rice          0          0       362   2.7       7.5
# 7             Cauliflower          0          0        32   0.3       3.0
# ..                    ...        ...        ...       ...   ...       ...
# 153       wai wai noodles          0          1       270   9.0       7.0
# 154          chana masala          0          0       565  10.4      18.5
# 155       chini ko laddhu          0          0         5   0.3       0.1
# 157         Hide and Sick          0          0       750  27.0       9.0
# 158                Donuts          0          0       310  18.0       4.0
#
#       Iron  Calcium  Sodium  Potassium  Carbohydrates  Fibre  VitaminD  Sugars
# ...

# %%
#breakfast_data datas
breakfast_df=df[df['Breakfast']==1][['Food_items','VegNovVeg','Junk Food','Calories', 'Fats', 'Proteins', 'Iron', 'Calcium', 'Sodium', 'Potassium', 'Carbohydrates', 'Fibre', 'VitaminD', 'Sugars']]
breakfast_df.to_csv('Data-sets/breakfast')

# %%
breakfast_df
# Out:
#                 Food_items  VegNovVeg  Junk Food  Calories  Fats  Proteins  \
# 1                 Avocados          0          0       160  15.0       2.0
# 2                  Bananas          0          0        89   0.3       1.1
# 4                  Berries          0          0       349   0.4      14.0
# 8          American cheese          0          0       331  24.0      20.0
# 9                   Coffee          0          0         2   0.0       0.3
# 10                    Corn          0          0        97   1.4       3.3
# 12                  Grapes          0          0        93   2.1       5.6
# 13                    Milk          0          0        97   6.9       3.8
# 14             Cashew Nuts          0          0       553  44.0      18.0
# 16                  Orange          0          0        97   0.2       1.5
# 18                   Pears          0          0        57   0.1       0.4
# ...

# %%
lunch_df['Calories'].mean()
# Out:
# 218.86163522012578
