# %%
import pandas as pd
import requests

# %%
response=requests.get("https://randomuser.me/api")
response.json()
# Out:
# {'results': [{'gender': 'female',
#    'name': {'title': 'Ms', 'first': 'Allie', 'last': 'Clarke'},
#    'location': {'street': {'number': 5322, 'name': 'Galway Road'},
#     'city': 'Gorey',
#     'state': 'Cavan',
#     'country': 'Ireland',
#     'postcode': 78475,
#     'coordinates': {'latitude': '3.7883', 'longitude': '170.3338'},
#     'timezone': {'offset': '-6:00',
#      'description': 'Central Time (US & Canada), Mexico City'}},
#    'email': 'allie.clarke@example.com',
#    'login': {'uuid': '02e38260-c94e-472e-9daf-e0ed57349463',
#     'username': 'yellowwolf156',
#     'password': 'oliver1',
#     'salt': 'Kr5Ej5h1',
#     'md5': 'a85923b6a35714c69499bcefca15a0df',
#     'sha1': '0639624e69fad82a5b6f90f2a025590b6b182e08',
#     'sha256': 'cef50e3b63753f37d55a908cd1716a90e6a9f1bd08593478da83b39285f94c64'},
#    'dob': {'date': '1996-12-03T16:33:13.263Z', 'age': 27},
#    'registered': {'date': '2019-03-24T10:33:00.757Z', 'age': 5},
#    'phone': '041-225-2420',
#    'cell': '081-737-7039',
#    'id': {'name': 'PPS', 'value': '9158046T'},
#    'picture': {'large': 'https://randomuser.me/api/portraits/women/34.jpg',
#     'medium': 'https://randomuser.me/api/portraits/med/women/34.jpg',
#     'thumbnail': 'https://randomuser.me/api/portraits/thumb/women/34.jpg'},
#    'nat': 'IE'}],
#  'info': {'seed': '0eb4ddbbf02a8a12',
#   'results': 1,
#   'page': 1,
#   'version': '1.4'}}

# %%
pd.DataFrame(response.json()['results'])
# Out:
#    gender                                               name  \
# 0  female  {'title': 'Ms', 'first': 'Allie', 'last': 'Cla...
#
#                                             location  \
# 0  {'street': {'number': 5322, 'name': 'Galway Ro...
#
#                       email  \
# 0  allie.clarke@example.com
#
#                                                login  \
# 0  {'uuid': '02e38260-c94e-472e-9daf-e0ed57349463...
#
#                                                dob  \
# 0  {'date': '1996-12-03T16:33:13.263Z', 'age': 27}
#
#                                        registered         phone          cell  \
# 0  {'date': '2019-03-24T10:33:00.757Z', 'age': 5}  041-225-2420  081-737-7039
#
#                                      id  \
# 0  {'name': 'PPS', 'value': '9158046T'}
#
#                                              picture nat
# 0  {'large': 'https://randomuser.me/api/portraits...  IE

# %%
response.json()['results'][0]['name']['first']
# Out:
# 'Allie'

# %%
# testing

# %%
url = "https://covid-193.p.rapidapi.com/statistics"

headers = {
	"X-RapidAPI-Key": "3962ee71b2msh7d9b32ceebdf518p1cc1ecjsn39ede50fa90f",
	"X-RapidAPI-Host": "covid-193.p.rapidapi.com"
}

response = requests.get(url, headers=headers)

pd.DataFrame(response.json()['response'])
# Out:
#          continent           country  population  \
# 0           Africa      Saint-Helena      6115.0
# 1    South-America  Falkland-Islands      3539.0
# 2    North-America        Montserrat      4965.0
# 3             None  Diamond-Princess         NaN
# 4           Europe      Vatican-City       799.0
# ..             ...               ...         ...
# 233         Europe           Denmark   5834950.0
# 234           Asia         Singapore   5943546.0
# 235  North-America     North-America         NaN
# 236           Asia              Asia         NaN
# 237         Europe            Europe         NaN
#
#                                                  cases  \
# 0    {'new': None, 'active': 2164, 'critical': None...
# 1    {'new': None, 'active': 0, 'critical': None, '...
# 2    {'new': None, 'active': 19, 'critical': None, ...
# 3    {'new': None, 'active': 0, 'critical': None, '...
# 4    {'new': None, 'active': 0, 'critical': None, '...
# ..                                                 ...
# 233  {'new': None, 'active': 0, 'critical': None, '...
# 234  {'new': None, 'active': 0, 'critical': 4, 'rec...
# 235  {'new': None, 'active': 2528062, 'critical': 6...
# 236  {'new': None, 'active': 14273512, 'critical': ...
# 237  {'new': None, 'active': 2550270, 'critical': 4...
#
#                                               deaths  \
# 0       {'new': None, '1M_pop': None, 'total': None}
# 1       {'new': None, '1M_pop': None, 'total': None}
# 2        {'new': None, '1M_pop': '1611', 'total': 8}
# 3         {'new': None, '1M_pop': None, 'total': 13}
# 4       {'new': None, '1M_pop': None, 'total': None}
# ..                                               ...
# 233   {'new': None, '1M_pop': '1511', 'total': 8814}
# 234    {'new': None, '1M_pop': '341', 'total': 2024}
# 235  {'new': None, '1M_pop': None, 'total': 1695941}
# 236  {'new': None, '1M_pop': None, 'total': 1553662}
# 237  {'new': None, '1M_pop': None, 'total': 2101824}
#
#                                           tests         day  \
# 0               {'1M_pop': None, 'total': None}  2024-04-27
# 1          {'1M_pop': '2439107', 'total': 8632}  2024-04-27
# 2         {'1M_pop': '3577442', 'total': 17762}  2024-04-27
# 3               {'1M_pop': None, 'total': None}  2024-04-27
# 4               {'1M_pop': None, 'total': None}  2024-04-27
# ..                                          ...         ...
# 233  {'1M_pop': '22165247', 'total': 129333107}  2024-04-27
# 234    {'1M_pop': '4165302', 'total': 24756666}  2024-04-27
# 235             {'1M_pop': None, 'total': None}  2024-04-27
# 236             {'1M_pop': None, 'total': None}  2024-04-27
# 237             {'1M_pop': None, 'total': None}  2024-04-27
#
#                           time
# 0    2024-04-27T16:30:09+00:00
# 1    2024-04-27T16:30:09+00:00
# 2    2024-04-27T16:30:09+00:00
# 3    2024-04-27T16:30:09+00:00
# 4    2024-04-27T16:30:09+00:00
# ..                         ...
# 233  2024-04-27T16:30:04+00:00
# 234  2024-04-27T16:30:04+00:00
# 235  2024-04-27T16:30:03+00:00
# 236  2024-04-27T16:30:03+00:00
# 237  2024-04-27T16:30:03+00:00
#
# [238 rows x 8 columns]

# %%
#test-2

# %%
import requests

url = "https://covid-193.p.rapidapi.com/countries"

headers = {
	"X-RapidAPI-Key": "3962ee71b2msh7d9b32ceebdf518p1cc1ecjsn39ede50fa90f",
	"X-RapidAPI-Host": "covid-193.p.rapidapi.com"
}

response = requests.get(url, headers=headers)

pd.DataFrame(response.json()['response'])
# Out:
#                      0
# 0          Afghanistan
# 1              Albania
# 2              Algeria
# 3              Andorra
# 4               Angola
# ..                 ...
# 226  Wallis-and-Futuna
# 227     Western-Sahara
# 228              Yemen
# 229             Zambia
# 230           Zimbabwe
#
# [231 rows x 1 columns]
